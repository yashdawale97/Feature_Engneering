# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Handling Missing Values

# %%
import pandas as pd

# %%
df= pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import numpy as np
df['Cabin_null'] = np.where(df['Cabin'].isnull(),1,0)

df['Cabin_null'].mean()
# Out:
# 0.7710437710437711

# %%
df.groupby(['Survived'])

# %%
df = pd.read_csv('titanic.csv',usecols=['Age','Fare','Survived'])

# %%
df.head(50)
# Out:
#     Survived   Age      Fare
# 0          0  22.0    7.2500
# 1          1  38.0   71.2833
# 2          1  26.0    7.9250
# 3          1  35.0   53.1000
# 4          0  35.0    8.0500
# 5          0   NaN    8.4583
# 6          0  54.0   51.8625
# 7          0   2.0   21.0750
# 8          1  27.0   11.1333
# 9          1  14.0   30.0708
# 10         1   4.0   16.7000
# 11         1  58.0   26.5500
# 12         0  20.0    8.0500
# 13         0  39.0   31.2750
# 14         0  14.0    7.8542
# 15         1  55.0   16.0000
# 16         0   2.0   29.1250
# 17         1   NaN   13.0000
# 18         0  31.0   18.0000
# 19         1   NaN    7.2250
# 20         0  35.0   26.0000
# 21         1  34.0   13.0000
# 22         1  15.0    8.0292
# 23         1  28.0   35.5000
# 24         0   8.0   21.0750
# 25         1  38.0   31.3875
# 26         0   NaN    7.2250
# 27         0  19.0  263.0000
# 28         1   NaN    7.8792
# 29         0   NaN    7.8958
# 30         0  40.0   27.7208
# 31         1   NaN  146.5208
# 32         1   NaN    7.7500
# 33         0  66.0   10.5000
# 34         0  28.0   82.1708
# 35         0  42.0   52.0000
# 36         1   NaN    7.2292
# 37         0  21.0    8.0500
# 38         0  18.0   18.0000
# 39         1  14.0   11.2417
# 40         0  40.0    9.4750
# 41         0  27.0   21.0000
# 42         0   NaN    7.8958
# 43         1   3.0   41.5792
# 44         1  19.0    7.8792
# 45         0   NaN    8.0500
# 46         0   NaN   15.5000
# 47         1   NaN    7.7500
# 48         0   NaN   21.6792
# 49         0  18.0   17.8000

# %%
df.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %% [markdown]
# ## Using Mean/Median

# %%
def impute_nan(df,varaible,median):
    df[varaible+'_median'] = df[varaible].fillna(median)

# %%
median = df.Age.median()
median
# Out:
# 28.0

# %%
impute_nan(df,'Age',median)
df.head(50)
# Out:
#     Survived   Age      Fare  Age_median
# 0          0  22.0    7.2500        22.0
# 1          1  38.0   71.2833        38.0
# 2          1  26.0    7.9250        26.0
# 3          1  35.0   53.1000        35.0
# 4          0  35.0    8.0500        35.0
# 5          0   NaN    8.4583        28.0
# 6          0  54.0   51.8625        54.0
# 7          0   2.0   21.0750         2.0
# 8          1  27.0   11.1333        27.0
# 9          1  14.0   30.0708        14.0
# 10         1   4.0   16.7000         4.0
# 11         1  58.0   26.5500        58.0
# 12         0  20.0    8.0500        20.0
# 13         0  39.0   31.2750        39.0
# 14         0  14.0    7.8542        14.0
# 15         1  55.0   16.0000        55.0
# 16         0   2.0   29.1250         2.0
# 17         1   NaN   13.0000        28.0
# 18         0  31.0   18.0000        31.0
# 19         1   NaN    7.2250        28.0
# 20         0  35.0   26.0000        35.0
# 21         1  34.0   13.0000        34.0
# 22         1  15.0    8.0292        15.0
# 23         1  28.0   35.5000        28.0
# 24         0   8.0   21.0750         8.0
# 25         1  38.0   31.3875        38.0
# 26         0   NaN    7.2250        28.0
# 27         0  19.0  263.0000        19.0
# 28         1   NaN    7.8792        28.0
# 29         0   NaN    7.8958        28.0
# 30         0  40.0   27.7208        40.0
# 31         1   NaN  146.5208        28.0
# 32         1   NaN    7.7500        28.0
# 33         0  66.0   10.5000        66.0
# 34         0  28.0   82.1708        28.0
# 35         0  42.0   52.0000        42.0
# 36         1   NaN    7.2292        28.0
# 37         0  21.0    8.0500        21.0
# 38         0  18.0   18.0000        18.0
# 39         1  14.0   11.2417        14.0
# 40         0  40.0    9.4750        40.0
# 41         0  27.0   21.0000        27.0
# 42         0   NaN    7.8958        28.0
# 43         1   3.0   41.5792         3.0
# 44         1  19.0    7.8792        19.0
# 45         0   NaN    8.0500        28.0
# 46         0   NaN   15.5000        28.0
# 47         1   NaN    7.7500        28.0
# 48         0   NaN   21.6792        28.0
# 49         0  18.0   17.8000        18.0

# %%
print(df['Age'].std())
print(df['Age_median'].std())
# Out:
# 14.526497332334044
# 13.019696550973194

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig =plt.figure()
ax = fig.add_subplot(111)
df['Age'].plot(kind='kde',ax = ax)
df.Age_median.plot(kind= 'kde',ax=ax, color='red')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels ,loc='best')

# %% [markdown]
# ## Using Random Value

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv',usecols=['Age','Fare','Survived'])
df.head(20)
# Out:
#     Survived   Age     Fare
# 0          0  22.0   7.2500
# 1          1  38.0  71.2833
# 2          1  26.0   7.9250
# 3          1  35.0  53.1000
# 4          0  35.0   8.0500
# 5          0   NaN   8.4583
# 6          0  54.0  51.8625
# 7          0   2.0  21.0750
# 8          1  27.0  11.1333
# 9          1  14.0  30.0708
# 10         1   4.0  16.7000
# 11         1  58.0  26.5500
# 12         0  20.0   8.0500
# 13         0  39.0  31.2750
# 14         0  14.0   7.8542
# 15         1  55.0  16.0000
# 16         0   2.0  29.1250
# 17         1   NaN  13.0000
# 18         0  31.0  18.0000
# 19         1   NaN   7.2250

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df['Age'].dropna().sample(df['Age'].isnull().sum(),random_state=0)
# Out:
# 640    20.0
# 617    26.0
# 104    37.0
# 401    26.0
# 190    32.0
#        ...
# 816    23.0
# 255    29.0
# 880    25.0
# 382    32.0
# 363    35.0
# Name: Age, Length: 177, dtype: float64

# %%
df[df['Age'].isnull()].index
# Out:
# Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#        ...
#        832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#       dtype='int64', length=177)

# %%
def impute_nan(df,variable,median):
    df[variable+'_median'] = df[variable].fillna(median)
    df[variable+'_random'] = df[variable]
    random_sample = df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
    random_sample.index = df[df[variable].isnull()].index
    df.loc[df[variable].isnull(),variable+'_random'] =random_sample

# %%
df['Age'].index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
impute_nan(df,'Age',median)

# %%
df.head(30)
# Out:
#     Survived   Age      Fare  Age_random  Age_median
# 0          0  22.0    7.2500       22.00        22.0
# 1          1  38.0   71.2833       38.00        38.0
# 2          1  26.0    7.9250       26.00        26.0
# 3          1  35.0   53.1000       35.00        35.0
# 4          0  35.0    8.0500       35.00        35.0
# 5          0   NaN    8.4583       28.00        28.0
# 6          0  54.0   51.8625       54.00        54.0
# 7          0   2.0   21.0750        2.00         2.0
# 8          1  27.0   11.1333       27.00        27.0
# 9          1  14.0   30.0708       14.00        14.0
# 10         1   4.0   16.7000        4.00         4.0
# 11         1  58.0   26.5500       58.00        58.0
# 12         0  20.0    8.0500       20.00        20.0
# 13         0  39.0   31.2750       39.00        39.0
# 14         0  14.0    7.8542       14.00        14.0
# 15         1  55.0   16.0000       55.00        55.0
# 16         0   2.0   29.1250        2.00         2.0
# 17         1   NaN   13.0000       50.00        28.0
# 18         0  31.0   18.0000       31.00        31.0
# 19         1   NaN    7.2250        0.92        28.0
# 20         0  35.0   26.0000       35.00        35.0
# 21         1  34.0   13.0000       34.00        34.0
# 22         1  15.0    8.0292       15.00        15.0
# 23         1  28.0   35.5000       28.00        28.0
# 24         0   8.0   21.0750        8.00         8.0
# 25         1  38.0   31.3875       38.00        38.0
# 26         0   NaN    7.2250       36.00        28.0
# 27         0  19.0  263.0000       19.00        19.0
# 28         1   NaN    7.8792       26.00        28.0
# 29         0   NaN    7.8958       36.00        28.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df['Age'].plot(kind='kde',ax=ax)
df.Age_median.plot(kind='kde',ax=ax,color='red')
df.Age_random.plot(kind='kde',ax=ax,color='green')
lines,labels = ax.get_legend_handles_labels()
ax.legend(lines,labels,loc='best')

# %%
df =pd.read_csv('titanic.csv' ,usecols=['Age','Fare','Survived'])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
import numpy as np
df['Age_nan'] = np.where(df['Age'].isnull(),1,0)

# %%
df.head(20)
# Out:
#     Survived   Age     Fare  Age_nan
# 0          0  22.0   7.2500        0
# 1          1  38.0  71.2833        0
# 2          1  26.0   7.9250        0
# 3          1  35.0  53.1000        0
# 4          0  35.0   8.0500        0
# 5          0   NaN   8.4583        1
# 6          0  54.0  51.8625        0
# 7          0   2.0  21.0750        0
# 8          1  27.0  11.1333        0
# 9          1  14.0  30.0708        0
# 10         1   4.0  16.7000        0
# 11         1  58.0  26.5500        0
# 12         0  20.0   8.0500        0
# 13         0  39.0  31.2750        0
# 14         0  14.0   7.8542        0
# 15         1  55.0  16.0000        0
# 16         0   2.0  29.1250        0
# 17         1   NaN  13.0000        1
# 18         0  31.0  18.0000        0
# 19         1   NaN   7.2250        1

# %%
df =pd.read_csv('titanic.csv' ,usecols=['Age','Fare','Survived'])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.Age.hist(bins=50)
# Out:
# <Axes: >

# %%
extreme= df.Age.mean()+3*df.Age.std()

# %%
def impute_nan(df,variable,median,extreme):
    df[variable+"_end_distribution"]=df[variable].fillna(extreme)
    df[variable].fillna(median,inplace=True)

# %%
extreme
# Out:
# 68.42067214450208

# %%
impute_nan(df,'Age',df.Age.median(),extreme)

# %%
df['Age'].hist(bins=50)
# Out:
# <Axes: >

# %%
.hist(bins=50)
# Out:
# <Axes: >

# %%
df['Age_end_distribution'].head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5     28.0
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17    28.0
# 18    31.0
# 19    28.0
# Name: Age_end_distribution, dtype: float64
